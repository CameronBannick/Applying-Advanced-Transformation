# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os,json

# %% [markdown]
# # Importing and Cleaning First Dataframe

# %%
#import first dataframe
info_df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vS1ZstYLwFgwhZnqDsPjtnlHYhJp_cmW55J8JD5mym0seRsaem3px7QBtuFF0LiI7z1PLCkVKAkdO7J/pub?output=csv')
info_df.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
#check for duplicates/missing values
print(f'Superhero Info DF contains {info_df.duplicated().sum()} duplicates')
print(f'Superhero Info DF contains {info_df.isna().sum().sum()} Missing Values')
# Out:
# Superhero Info DF contains 0 duplicates
# Superhero Info DF contains 0 Missing Values

# %%
#checking info on info_df
info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB

# %%
#splitting Hero|Publsiher column into two seperate columns
info_df['Hero|Publisher'].head(2)
# Out:
# 0            A-Bomb|Marvel Comics
# 1    Abe Sapien|Dark Horse Comics
# Name: Hero|Publisher, dtype: object

# %%
info_df[['Hero', 'Publisher']] = info_df['Hero|Publisher'].str.split('|', expand=True)
info_df.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
#dropping old Hero|Publisher column
info_df = info_df.drop(columns='Hero|Publisher')
info_df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero          Publisher
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb      Marvel Comics
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien  Dark Horse Comics

# %%
#inspecting Measurements dictionary
measr = info_df.loc[0, 'Measurements']
print(f'Measurements Column is a {type(measr)} type')
measr
# Out:
# Measurements Column is a <class 'str'> type
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %% [markdown]
# Since there are single quotes present, we will need them to replaced with double quotes in order to get JSON to work with the data

# %%
#adjusting quotes to ensure data readable by JSON
info_df['Measurements'] = info_df['Measurements'].str.replace("'", '"')
info_df['Measurements'] = info_df['Measurements'].apply(json.loads)
info_df['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
#test to ensure success in previous cell
test = info_df.loc[0, 'Measurements']
print(f'Measurement Column is now a {type(test)} type')
test
# Out:
# Measurement Column is now a <class 'dict'> type
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
#creating a series based on Measurements Dictionary
hite_wate = info_df['Measurements'].apply(pd.Series)
hite_wate
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
#combining series with info dataframe
info_df = pd.concat((info_df, hite_wate), axis=1)
info_df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
#dropping now redundant Measurements Column
info_df = info_df.drop(columns='Measurements')
info_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height    Weight
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0 kg
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0 kg
# 2       Abin Sur          DC Comics  185.0 cm   90.0 kg
# 3    Abomination      Marvel Comics  203.0 cm  441.0 kg
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0 kg

# %%
info_df['Height'] = info_df['Height'].str.replace(' cm', '')

# %%
info_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height    Weight
# 0         A-Bomb      Marvel Comics  203.0  441.0 kg
# 1     Abe Sapien  Dark Horse Comics  191.0   65.0 kg
# 2       Abin Sur          DC Comics  185.0   90.0 kg
# 3    Abomination      Marvel Comics  203.0  441.0 kg
# 4  Absorbing Man      Marvel Comics  193.0  122.0 kg

# %%
info_df['Weight'] = info_df['Weight'].str.replace(' kg', '')
info_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height Weight
# 0         A-Bomb      Marvel Comics  203.0  441.0
# 1     Abe Sapien  Dark Horse Comics  191.0   65.0
# 2       Abin Sur          DC Comics  185.0   90.0
# 3    Abomination      Marvel Comics  203.0  441.0
# 4  Absorbing Man      Marvel Comics  193.0  122.0

# %%
info_df['Height'] = pd.to_numeric(info_df['Height'])
info_df['Weight']= pd.to_numeric(info_df['Weight'])
info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    float64
#  9   Weight      463 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 36.3+ KB

# %% [markdown]
# # Importing and Cleaning Second Dataset

# %%
#importing power_df
power_df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSzdWOBaXOoz52vPmCFV5idNlDBohLY1Lsbc1IfZIZQ7cV_aNB2wYBfhF49uE1TaO1B5MQCGWiNrFfd/pub?output=csv')
power_df.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
#check for duplicates/missing values
print(f'Superhero Power DF contains {power_df.duplicated().sum()} duplicates')
print(f'Superhero Power DF contains {power_df.isna().sum().sum()} Missing Values')
# Out:
# Superhero Power DF contains 0 duplicates
# Superhero Power DF contains 0 Missing Values

# %%
#inspecting info
power_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB

# %%
#inspecting powers column
power = power_df.loc[0, 'Powers']
print(f'The Powers Column is a {type(power)} type')
power
# Out:
# The Powers Column is a <class 'str'> type
# 'Agility,Super Strength,Stamina,Super Speed'

# %% [markdown]
# All powers are labeled in a single string. Will use expand to fix

# %%
#turn to list 
power_df['Power_Split']=power_df['Powers'].str.split(',', expand=False)
power_df.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                          Power_Split
# 0    [Agility, Super Strength, Stamina, Super Speed]
# 1  [Accelerated Healing, Durability, Longevity, S...
# 2  [Agility, Accelerated Healing, Cold Resistance...
# 3                               [Lantern Power Ring]
# 4  [Accelerated Healing, Intelligence, Super Stre...

# %%
#inspecting powers column
power = power_df.loc[0, 'Power_Split']
print(f'The Powers Column is a {type(power)} type')
power
# Out:
# The Powers Column is a <class 'list'> type
# ['Agility', 'Super Strength', 'Stamina', 'Super Speed']

# %%
power_df['Power_Split'].value_counts()
# Out:
# [Intelligence]                                                                                                                                                                                                                                                                          8
# [Durability, Super Strength]                                                                                                                                                                                                                                                            5
# [Agility, Stealth, Marksmanship, Weapons Master, Stamina]                                                                                                                                                                                                                               4
# ...

# %%
#sepearting powers from list
exploded = power_df.explode('Power_Split')
exploded.head()
# Out:
#   hero_names                                             Powers  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#            Power_Split
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %%
#cols_to_make variable for loop
cols_to_make = exploded['Power_Split'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
#loop for hot encoding
for col in cols_to_make:
    power_df[col]=power_df['Powers'].str.contains(col)
#inspect results
power_df.head()
# Out:
# C:\Users\camer\AppData\Local\Temp\ipykernel_18424\2809585016.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   power_df[col]=power_df['Powers'].str.contains(col)
# C:\Users\camer\AppData\Local\Temp\ipykernel_18424\2809585016.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   power_df[col]=power_df['Powers'].str.contains(col)
# ...

# %%
#dropping Powers and Powers_Spilt Column
power_df = power_df.drop(columns=['Powers','Power_Split'])
power_df.head()
# Out:
#     hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0      3-D Man     True            True     True         True
# 1       A-Bomb    False            True     True        False
# 2   Abe Sapien     True            True     True        False
# 3     Abin Sur    False           False    False        False
# 4  Abomination    False            True     True         True
#
#    Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# 0                False       False      False       False            False
# 1                 True        True       True        True             True
# 2                 True        True       True       False            False
# 3                False       False      False       False            False
# 4                 True       False      False       False            False
#
#    ...  Weather Control  Omnipresent  Omniscient  Hair Manipulation  \
# 0  ...            False        False       False              False
# ...

# %% [markdown]
# # Combining Dataframes

# %%
#combine both dfs
hero_df = pd.merge(info_df, power_df, left_on='Hero', right_on='hero_names')
hero_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics   203.0   441.0  ...           False
# 1     Abe Sapien  Dark Horse Comics   191.0    65.0  ...           False
# 2       Abin Sur          DC Comics   185.0    90.0  ...           False
# 3    Abomination      Marvel Comics   203.0   441.0  ...           False
# 4  Absorbing Man      Marvel Comics   193.0   122.0  ...           False
#
#    Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# Compare the average weight of super powers who have Super Speed to those who do not.

# %%
#creating variable with groupby
speed8=hero_df.groupby('Super Speed')['Weight'].mean()
speed8
# Out:
# Super Speed
# False    101.773585
# True     129.404040
# Name: Weight, dtype: float64

# %%
#plotting variable
plt.bar(speed8.index, speed8.values)
plt.xlabel('Without Speed and With Speed')
plt.ylabel('Hero Weight')
plt.title('Comparing Avg Weight of Heros With and Without Super Speed')
plt.show()

# %% [markdown]
# What is the average height of heroes for each publisher?

# %%
#creating variable for question
hitepub = hero_df.groupby('Publisher')['Height'].mean()
hitepub
# Out:
# Publisher
# DC Comics            181.923913
# Dark Horse Comics    176.909091
# George Lucas         159.600000
# Image Comics         211.000000
# Marvel Comics        191.546128
# Shueisha             171.500000
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Name: Height, dtype: float64

# %%
#plotting variable
plt.bar(hitepub.index, hitepub.values)
plt.xlabel('Publisher')
plt.xticks( rotation ='vertical')
  
plt.ylabel('Hero Height')
plt.title('Comparing Avg Height of Heros by Publisher')
plt.show()
